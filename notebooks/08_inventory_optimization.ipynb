# %% [markdown]
# # RetailPulse Inventory Optimization
#
# ## Business Objective
#
# Optimize inventory levels and identify reorder requirements using SKU demand patterns.

# %%
import pandas as pd

df = pd.read_csv(
    "../data/dataset_3_sku_level_inventory_forecasting.csv.csv"
)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(
#       4     "../data/dataset_3_sku_level_inventory_forecasting.csv.csv"
#       5 )
#       6
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/dataset_3_sku_level_inventory_forecasting.csv.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    "../data/dataset_3_sku_level_inventory_forecasting.csv"
)

df.head()
# Out:
#   StockCode                  Description  Total_Quantity_Sold  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE                  8671        6942.26
# 1     10080     GROOVY CACTUS INFLATABLE                  315         129.29
# 2     10109         BENDY COLOUR PENCILS                    4           1.68
# 3     10120                 DOGGY RUBBER                  664         142.74
# 4     10125      MINI FUNKY DESIGN TAPES                 2103        1715.78
#
#    Avg_Price First_Sale_Date Last_Sale_Date  Num_Orders  Num_Countries_Sold  \
# 0   0.979155      2009-12-01     2011-04-18         362                  12
# 1   0.505000      2009-12-02     2011-11-21          27                   1
# 2   0.420000      2009-12-03     2009-12-03           1                   1
# 3   0.240137      2009-12-01     2011-12-04          73                   2
# 4   0.930636      2009-12-01     2011-12-09         167                   6
#
#    SKU_Demand_Velocity  Return_Rate  Average_Daily_Demand  Gross_Quantity  \
# 0            38.537778     0.135693             17.204365          9013.0
# 1            12.115385     0.000000              0.437500           597.0
# 2             4.000000     0.000000              4.000000             0.0
# 3            10.375000    -0.003606              0.904632         -8320.0
# 4            16.959677     0.000000              2.845737          2151.0
#
#    Return_Quantity  Net_Quantity  Product_Lifespan_Days
# 0           1223.0        7790.0                    504
# 1              0.0         597.0                    720
# 2              0.0           0.0                      1
# 3             30.0       -8350.0                    734
# 4              0.0        2151.0                    739

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4917 entries, 0 to 4916
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StockCode              4917 non-null   str
#  1   Description            4917 non-null   str
#  2   Total_Quantity_Sold    4917 non-null   int64
#  3   Total_Revenue          4917 non-null   float64
#  4   Avg_Price              4917 non-null   float64
#  5   First_Sale_Date        4917 non-null   str
#  6   Last_Sale_Date         4917 non-null   str
#  7   Num_Orders             4917 non-null   int64
#  8   Num_Countries_Sold     4917 non-null   int64
#  9   SKU_Demand_Velocity    4917 non-null   float64
#  10  Return_Rate            4917 non-null   float64
#  11  Average_Daily_Demand   4917 non-null   float64
#  12  Gross_Quantity         4917 non-null   float64
#  13  Return_Quantity        4917 non-null   float64
#  14  Net_Quantity           4917 non-null   float64
#  15  Product_Lifespan_Days  4917 non-null   int64
# dtypes: float64(8), int64(4), str(4)
# memory usage: 614.8 KB

# %%
df.columns
# Out:
# Index(['StockCode', 'Description', 'Total_Quantity_Sold', 'Total_Revenue',
#        'Avg_Price', 'First_Sale_Date', 'Last_Sale_Date', 'Num_Orders',
#        'Num_Countries_Sold', 'SKU_Demand_Velocity', 'Return_Rate',
#        'Average_Daily_Demand', 'Gross_Quantity', 'Return_Quantity',
#        'Net_Quantity', 'Product_Lifespan_Days'],
#       dtype='str')

# %%
import pandas as pd

df = pd.read_csv(
    "../data/dataset_3_sku_level_inventory_forecasting.csv"
)

df.head()
# Out:
#   StockCode                  Description  Total_Quantity_Sold  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE                  8671        6942.26
# 1     10080     GROOVY CACTUS INFLATABLE                  315         129.29
# 2     10109         BENDY COLOUR PENCILS                    4           1.68
# 3     10120                 DOGGY RUBBER                  664         142.74
# 4     10125      MINI FUNKY DESIGN TAPES                 2103        1715.78
#
#    Avg_Price First_Sale_Date Last_Sale_Date  Num_Orders  Num_Countries_Sold  \
# 0   0.979155      2009-12-01     2011-04-18         362                  12
# 1   0.505000      2009-12-02     2011-11-21          27                   1
# 2   0.420000      2009-12-03     2009-12-03           1                   1
# 3   0.240137      2009-12-01     2011-12-04          73                   2
# 4   0.930636      2009-12-01     2011-12-09         167                   6
#
#    SKU_Demand_Velocity  Return_Rate  Average_Daily_Demand  Gross_Quantity  \
# 0            38.537778     0.135693             17.204365          9013.0
# 1            12.115385     0.000000              0.437500           597.0
# 2             4.000000     0.000000              4.000000             0.0
# 3            10.375000    -0.003606              0.904632         -8320.0
# 4            16.959677     0.000000              2.845737          2151.0
#
#    Return_Quantity  Net_Quantity  Product_Lifespan_Days
# 0           1223.0        7790.0                    504
# 1              0.0         597.0                    720
# 2              0.0           0.0                      1
# 3             30.0       -8350.0                    734
# 4              0.0        2151.0                    739

# %%
print(df.columns.tolist())
# Out:
# ['StockCode', 'Description', 'Total_Quantity_Sold', 'Total_Revenue', 'Avg_Price', 'First_Sale_Date', 'Last_Sale_Date', 'Num_Orders', 'Num_Countries_Sold', 'SKU_Demand_Velocity', 'Return_Rate', 'Average_Daily_Demand', 'Gross_Quantity', 'Return_Quantity', 'Net_Quantity', 'Product_Lifespan_Days']

# %%
inventory_df = df.copy()

inventory_df["Safety_Stock"] = (
    inventory_df["Average_Daily_Demand"] * 7
)

inventory_df["Reorder_Point"] = (
    inventory_df["Average_Daily_Demand"] * 14
)

inventory_df["Inventory_Gap"] = (
    inventory_df["Reorder_Point"]
    - inventory_df["Net_Quantity"]
)

inventory_df.head()
# Out:
#   StockCode                  Description  Total_Quantity_Sold  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE                  8671        6942.26
# 1     10080     GROOVY CACTUS INFLATABLE                  315         129.29
# 2     10109         BENDY COLOUR PENCILS                    4           1.68
# 3     10120                 DOGGY RUBBER                  664         142.74
# 4     10125      MINI FUNKY DESIGN TAPES                 2103        1715.78
#
#    Avg_Price First_Sale_Date Last_Sale_Date  Num_Orders  Num_Countries_Sold  \
# 0   0.979155      2009-12-01     2011-04-18         362                  12
# 1   0.505000      2009-12-02     2011-11-21          27                   1
# 2   0.420000      2009-12-03     2009-12-03           1                   1
# 3   0.240137      2009-12-01     2011-12-04          73                   2
# 4   0.930636      2009-12-01     2011-12-09         167                   6
#
#    SKU_Demand_Velocity  Return_Rate  Average_Daily_Demand  Gross_Quantity  \
# 0            38.537778     0.135693             17.204365          9013.0
# 1            12.115385     0.000000              0.437500           597.0
# 2             4.000000     0.000000              4.000000             0.0
# 3            10.375000    -0.003606              0.904632         -8320.0
# 4            16.959677     0.000000              2.845737          2151.0
#
#    Return_Quantity  Net_Quantity  Product_Lifespan_Days  Safety_Stock  \
# 0           1223.0        7790.0                    504    120.430556
# 1              0.0         597.0                    720      3.062500
# 2              0.0           0.0                      1     28.000000
# 3             30.0       -8350.0                    734      6.332425
# 4              0.0        2151.0                    739     19.920162
#
#    Reorder_Point  Inventory_Gap
# 0     240.861111   -7549.138889
# 1       6.125000    -590.875000
# 2      56.000000      56.000000
# 3      12.664850    8362.664850
# 4      39.840325   -2111.159675

# %%
inventory_df["Stock_Status"] = "Optimal"

inventory_df.loc[
    inventory_df["Net_Quantity"]
    < inventory_df["Reorder_Point"],
    "Stock_Status"
] = "Reorder Required"

inventory_df.loc[
    inventory_df["Net_Quantity"]
    >
    inventory_df["Reorder_Point"] * 1.5,
    "Stock_Status"
] = "Overstock"

inventory_df["Stock_Status"].value_counts()
# Out:
# Stock_Status
# Overstock           4456
# Reorder Required     434
# Optimal               27
# Name: count, dtype: int64

# %%
inventory_df["Recommendation"] = (
    inventory_df["Stock_Status"]
)

inventory_df.loc[
    inventory_df["Stock_Status"]
    == "Reorder Required",
    "Recommendation"
] = "Reorder Immediately"

inventory_df.loc[
    inventory_df["Stock_Status"]
    == "Optimal",
    "Recommendation"
] = "Maintain Current Stock"

inventory_df.loc[
    inventory_df["Stock_Status"]
    == "Overstock",
    "Recommendation"
] = "Reduce Future Orders"

inventory_df.head()
# Out:
#   StockCode                  Description  Total_Quantity_Sold  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE                  8671        6942.26
# 1     10080     GROOVY CACTUS INFLATABLE                  315         129.29
# 2     10109         BENDY COLOUR PENCILS                    4           1.68
# 3     10120                 DOGGY RUBBER                  664         142.74
# 4     10125      MINI FUNKY DESIGN TAPES                 2103        1715.78
#
#    Avg_Price First_Sale_Date Last_Sale_Date  Num_Orders  Num_Countries_Sold  \
# 0   0.979155      2009-12-01     2011-04-18         362                  12
# 1   0.505000      2009-12-02     2011-11-21          27                   1
# 2   0.420000      2009-12-03     2009-12-03           1                   1
# 3   0.240137      2009-12-01     2011-12-04          73                   2
# 4   0.930636      2009-12-01     2011-12-09         167                   6
#
#    SKU_Demand_Velocity  ...  Average_Daily_Demand  Gross_Quantity  \
# 0            38.537778  ...             17.204365          9013.0
# 1            12.115385  ...              0.437500           597.0
# 2             4.000000  ...              4.000000             0.0
# 3            10.375000  ...              0.904632         -8320.0
# 4            16.959677  ...              2.845737          2151.0
#
#    Return_Quantity  Net_Quantity  Product_Lifespan_Days  Safety_Stock  \
# 0           1223.0        7790.0                    504    120.430556
# 1              0.0         597.0                    720      3.062500
# 2              0.0           0.0                      1     28.000000
# 3             30.0       -8350.0                    734      6.332425
# 4              0.0        2151.0                    739     19.920162
#
#    Reorder_Point  Inventory_Gap      Stock_Status        Recommendation
# 0     240.861111   -7549.138889         Overstock  Reduce Future Orders
# 1       6.125000    -590.875000         Overstock  Reduce Future Orders
# 2      56.000000      56.000000  Reorder Required   Reorder Immediately
# 3      12.664850    8362.664850  Reorder Required   Reorder Immediately
# 4      39.840325   -2111.159675         Overstock  Reduce Future Orders
#
# [5 rows x 21 columns]

# %%
print(
    inventory_df["Stock_Status"]
    .value_counts()
)
# Out:
# Stock_Status
# Overstock           4456
# Reorder Required     434
# Optimal               27
# Name: count, dtype: int64

# %%
reorder_count = (
    inventory_df["Stock_Status"]
    == "Reorder Required"
).sum()

overstock_count = (
    inventory_df["Stock_Status"]
    == "Overstock"
).sum()

print(
    f"Reorder Required: {reorder_count}"
)

print(
    f"Overstock: {overstock_count}"
)
# Out:
# Reorder Required: 434
# Overstock: 4456

# %%
inventory_output = inventory_df[
    [
        "StockCode",
        "Description",
        "Average_Daily_Demand",
        "Net_Quantity",
        "Safety_Stock",
        "Reorder_Point",
        "Inventory_Gap",
        "Stock_Status",
        "Recommendation"
    ]
]

inventory_output.to_csv(
    "../outputs/inventory_recommendations.csv",
    index=False
)

print(
    "inventory_recommendations.csv saved"
)
# Out:
# inventory_recommendations.csv saved

# %%
df["Inventory_Status"] = df["Inventory_Gap"].apply(
    lambda x: "Restock Required"
    if x > 0
    else "Sufficient Stock"
)

df[
    [
        "StockCode",
        "Net_Quantity",
        "Reorder_Point",
        "Inventory_Gap",
        "Inventory_Status"
    ]
].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Inventory_Gap'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df["Inventory_Status"] = df["Inventory_Gap"].apply(
#       2     lambda x: "Restock Required"
#       3     if x > 0
#       4     else "Sufficient Stock"
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File e:\RetailPulse project\RetailPulse-Zidio\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Inventory_Gap'

# %%
print(df.columns.tolist())
# Out:
# ['StockCode', 'Description', 'Total_Quantity_Sold', 'Total_Revenue', 'Avg_Price', 'First_Sale_Date', 'Last_Sale_Date', 'Num_Orders', 'Num_Countries_Sold', 'SKU_Demand_Velocity', 'Return_Rate', 'Average_Daily_Demand', 'Gross_Quantity', 'Return_Quantity', 'Net_Quantity', 'Product_Lifespan_Days']

# %%
df["Safety_Stock"] = df["Average_Daily_Demand"] * 7

df["Reorder_Point"] = df["Average_Daily_Demand"] * 14

df["Inventory_Gap"] = (
    df["Reorder_Point"]
    - df["Net_Quantity"]
)

df.head()
# Out:
#   StockCode                  Description  Total_Quantity_Sold  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE                  8671        6942.26
# 1     10080     GROOVY CACTUS INFLATABLE                  315         129.29
# 2     10109         BENDY COLOUR PENCILS                    4           1.68
# 3     10120                 DOGGY RUBBER                  664         142.74
# 4     10125      MINI FUNKY DESIGN TAPES                 2103        1715.78
#
#    Avg_Price First_Sale_Date Last_Sale_Date  Num_Orders  Num_Countries_Sold  \
# 0   0.979155      2009-12-01     2011-04-18         362                  12
# 1   0.505000      2009-12-02     2011-11-21          27                   1
# 2   0.420000      2009-12-03     2009-12-03           1                   1
# 3   0.240137      2009-12-01     2011-12-04          73                   2
# 4   0.930636      2009-12-01     2011-12-09         167                   6
#
#    SKU_Demand_Velocity  Return_Rate  Average_Daily_Demand  Gross_Quantity  \
# 0            38.537778     0.135693             17.204365          9013.0
# 1            12.115385     0.000000              0.437500           597.0
# 2             4.000000     0.000000              4.000000             0.0
# 3            10.375000    -0.003606              0.904632         -8320.0
# 4            16.959677     0.000000              2.845737          2151.0
#
#    Return_Quantity  Net_Quantity  Product_Lifespan_Days  Safety_Stock  \
# 0           1223.0        7790.0                    504    120.430556
# 1              0.0         597.0                    720      3.062500
# 2              0.0           0.0                      1     28.000000
# 3             30.0       -8350.0                    734      6.332425
# 4              0.0        2151.0                    739     19.920162
#
#    Reorder_Point  Inventory_Gap
# 0     240.861111   -7549.138889
# 1       6.125000    -590.875000
# 2      56.000000      56.000000
# 3      12.664850    8362.664850
# 4      39.840325   -2111.159675

# %%
print(df.columns.tolist())
# Out:
# ['StockCode', 'Description', 'Total_Quantity_Sold', 'Total_Revenue', 'Avg_Price', 'First_Sale_Date', 'Last_Sale_Date', 'Num_Orders', 'Num_Countries_Sold', 'SKU_Demand_Velocity', 'Return_Rate', 'Average_Daily_Demand', 'Gross_Quantity', 'Return_Quantity', 'Net_Quantity', 'Product_Lifespan_Days', 'Safety_Stock', 'Reorder_Point', 'Inventory_Gap']

# %%
df["Inventory_Status"] = df["Inventory_Gap"].apply(
    lambda x: "Restock Required"
    if x > 0
    else "Sufficient Stock"
)

df[
    [
        "StockCode",
        "Net_Quantity",
        "Reorder_Point",
        "Inventory_Gap",
        "Inventory_Status"
    ]
].head()
# Out:
#   StockCode  Net_Quantity  Reorder_Point  Inventory_Gap  Inventory_Status
# 0     10002        7790.0     240.861111   -7549.138889  Sufficient Stock
# 1     10080         597.0       6.125000    -590.875000  Sufficient Stock
# 2     10109           0.0      56.000000      56.000000  Restock Required
# 3     10120       -8350.0      12.664850    8362.664850  Restock Required
# 4     10125        2151.0      39.840325   -2111.159675  Sufficient Stock

# %%
df["Inventory_Status"].value_counts()
# Out:
# Inventory_Status
# Sufficient Stock    4483
# Restock Required     434
# Name: count, dtype: int64

# %%
df.to_csv(
    "../outputs/inventory_recommendations.csv",
    index=False
)

print("Inventory Export Complete")
# Out:
# Inventory Export Complete

# %%
df["Recommendation"] = df["Inventory_Status"].apply(
    lambda x: "Order Immediately"
    if x == "Restock Required"
    else "Monitor Stock"
)

df.head()
# Out:
#   StockCode                  Description  Total_Quantity_Sold  Total_Revenue  \
# 0     10002  INFLATABLE POLITICAL GLOBE                  8671        6942.26
# 1     10080     GROOVY CACTUS INFLATABLE                  315         129.29
# 2     10109         BENDY COLOUR PENCILS                    4           1.68
# 3     10120                 DOGGY RUBBER                  664         142.74
# 4     10125      MINI FUNKY DESIGN TAPES                 2103        1715.78
#
#    Avg_Price First_Sale_Date Last_Sale_Date  Num_Orders  Num_Countries_Sold  \
# 0   0.979155      2009-12-01     2011-04-18         362                  12
# 1   0.505000      2009-12-02     2011-11-21          27                   1
# 2   0.420000      2009-12-03     2009-12-03           1                   1
# 3   0.240137      2009-12-01     2011-12-04          73                   2
# 4   0.930636      2009-12-01     2011-12-09         167                   6
#
#    SKU_Demand_Velocity  ...  Average_Daily_Demand  Gross_Quantity  \
# 0            38.537778  ...             17.204365          9013.0
# 1            12.115385  ...              0.437500           597.0
# 2             4.000000  ...              4.000000             0.0
# 3            10.375000  ...              0.904632         -8320.0
# 4            16.959677  ...              2.845737          2151.0
#
#    Return_Quantity  Net_Quantity  Product_Lifespan_Days  Safety_Stock  \
# 0           1223.0        7790.0                    504    120.430556
# 1              0.0         597.0                    720      3.062500
# 2              0.0           0.0                      1     28.000000
# 3             30.0       -8350.0                    734      6.332425
# 4              0.0        2151.0                    739     19.920162
#
#    Reorder_Point  Inventory_Gap  Inventory_Status     Recommendation
# 0     240.861111   -7549.138889  Sufficient Stock      Monitor Stock
# 1       6.125000    -590.875000  Sufficient Stock      Monitor Stock
# 2      56.000000      56.000000  Restock Required  Order Immediately
# 3      12.664850    8362.664850  Restock Required  Order Immediately
# 4      39.840325   -2111.159675  Sufficient Stock      Monitor Stock
#
# [5 rows x 21 columns]

# %%
df.to_csv(
    "../outputs/inventory_recommendations.csv",
    index=False
)
